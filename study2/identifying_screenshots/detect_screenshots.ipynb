# %%
import pandas as pd
import numpy as np
import urllib.request 
import os
import glob
import os.path

# %%
file_paths=[]
path_2022_02 = "/project/ll_774_951/uk_ru/twitter/data/2022-02/*.csv"
for fname in glob.glob(path_2022_02):
    file_paths.append(fname)
path_2022_03 = "/project/ll_774_951/uk_ru/twitter/data/2022-03/*.csv"
for fname in glob.glob(path_2022_03):
    file_paths.append(fname)
path_2022_04 = "/project/ll_774_951/uk_ru/twitter/data/2022-04/*.csv"
for fname in glob.glob(path_2022_04):
    file_paths.append(fname)
file_paths.sort()

tweets_urls=set()
for file in file_paths[0:1]:
    df = pd.read_csv(file,  engine='python', error_bad_lines=False)
    tweet_id = df['tweetid']
    tweet_id = tweet_id.dropna()
    tweet_id = tweet_id.reset_index(drop=True)
    for i in tweet_id:
        url = "https://twitter.com/anyuser/status/" + str(i)
        tweets_urls.add(url)

#tweets_urls
# we can randomly select unique tweets_urls for doing screenshots
# Out:
# Skipping line 122: Expected 66 fields in line 122, saw 76
# Skipping line 171: Expected 66 fields in line 171, saw 76
# Skipping line 332: Expected 66 fields in line 332, saw 76
# Skipping line 459: Expected 66 fields in line 459, saw 76
# Skipping line 514: Expected 66 fields in line 514, saw 76
# Skipping line 605: Expected 66 fields in line 605, saw 76
# Skipping line 708: Expected 66 fields in line 708, saw 76
# Skipping line 835: Expected 66 fields in line 835, saw 76
# Skipping line 1112: Expected 66 fields in line 1112, saw 76
# Skipping line 1159: Expected 66 fields in line 1159, saw 76
# Skipping line 1332: Expected 66 fields in line 1332, saw 76
# Skipping line 1347: Expected 66 fields in line 1347, saw 76
# Skipping line 1370: Expected 66 fields in line 1370, saw 76
# Skipping line 1797: Expected 66 fields in line 1797, saw 76
# Skipping line 1964: Expected 66 fields in line 1964, saw 76
# Skipping line 2157: Expected 66 fields in line 2157, saw 76
# ...

# %%
# binary image classification problem
# have not yet created training data and test data. wait for the instructions

# %%
# we will use convolutional neural network to detect the screenshots. It's a binary classification problem.
# input layer will be an image; the output layer will be the binary decision: if a screenshot or not
# reference https://www.analyticsvidhya.com/blog/2021/08/beginners-guide-to-convolutional-neural-network-with-implementation-in-python/

# %%
#importing the required libraries
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPool2D
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Dense

# %%
#defining model
model=Sequential()
#adding convolution layer
model.add(Conv2D(32,(3,3),activation='relu',input_shape=(28,28,1)))
#adding pooling layer
model.add(MaxPool2D(2,2))
#adding fully connected layer
model.add(Flatten())
model.add(Dense(100,activation='relu'))
#adding output layer
model.add(Dense(10,activation='softmax'))
#compiling the model
model.compile(loss='sparse_categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
#fitting the model
